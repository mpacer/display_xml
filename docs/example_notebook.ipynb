# %% [markdown]
# # Example Notebook for display_xml

# %% [markdown]
# By default the output is folded.

# %%
from display_xml import XML
XML('<body><tag>content</tag></body>')
# Out:
#     <div class="aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b">
#         <style>
#             div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .hll { background-color: #ffffcc }
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .c { color: #408080; font-style: italic } /* Comment */
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .err { border: 1px solid #FF0000 } /* Error */
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .k { color: #008000; font-weight: bold } /* Keyword */
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .o { color: #666666 } /* Operator */
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .cp { color: #BC7A00 } /* Comment.Preproc */
# div.aa6cbff20-28f0-4b3b-b73f-3010b2d13e8b .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# ...

# %% [markdown]
# To expand all elements by default, use `expand=True`.

# %%
XML('<body><tag>content</tag></body>', expand=True)
# Out:
#     <div class="acb9e8ee3-341a-43e0-b8c9-2a50b4b33835">
#         <style>
#             div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .hll { background-color: #ffffcc }
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .c { color: #408080; font-style: italic } /* Comment */
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .err { border: 1px solid #FF0000 } /* Error */
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .k { color: #008000; font-weight: bold } /* Keyword */
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .o { color: #666666 } /* Operator */
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .cp { color: #BC7A00 } /* Comment.Preproc */
# div.acb9e8ee3-341a-43e0-b8c9-2a50b4b33835 .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# ...

# %% [markdown]
# Set `pretty_print` to control the width of the indentation level. The default is 1

# %%
XML('<body><tag>content</tag></body>', expand=True, pretty_print=0)
# Out:
#     <div class="a9e17226a-1d5a-4b8c-b589-e35462228b36">
#         <style>
#             div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .hll { background-color: #ffffcc }
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .c { color: #408080; font-style: italic } /* Comment */
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .err { border: 1px solid #FF0000 } /* Error */
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .k { color: #008000; font-weight: bold } /* Keyword */
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .o { color: #666666 } /* Operator */
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .cp { color: #BC7A00 } /* Comment.Preproc */
# div.a9e17226a-1d5a-4b8c-b589-e35462228b36 .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# ...

# %%
XML('<body><tag>content</tag></body>', expand=True, pretty_print=3)
# Out:
#     <div class="a0fb9b84b-cfc4-420c-bde2-8b86807d35b7">
#         <style>
#             div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .hll { background-color: #ffffcc }
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .c { color: #408080; font-style: italic } /* Comment */
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .err { border: 1px solid #FF0000 } /* Error */
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .k { color: #008000; font-weight: bold } /* Keyword */
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .o { color: #666666 } /* Operator */
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .cp { color: #BC7A00 } /* Comment.Preproc */
# div.a0fb9b84b-cfc4-420c-bde2-8b86807d35b7 .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# ...

# %% [markdown]
# ## Styles

# %%
XML.display_all_styles('<body><tag>content</tag></body>', expand=True)
# Out:
# <h3 style="margin-bottom:.3em"> default </h3>
#     <div class="abe11654b-49c3-4ecb-ae31-ead4592bd990">
#         <style>
#             div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .hll { background-color: #ffffcc }
# div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .c { color: #408080; font-style: italic } /* Comment */
# div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .err { border: 1px solid #FF0000 } /* Error */
# div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .k { color: #008000; font-weight: bold } /* Keyword */
# div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .o { color: #666666 } /* Operator */
# div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# div.abe11654b-49c3-4ecb-ae31-ead4592bd990 .cp { color: #BC7A00 } /* Comment.Preproc */
# ...

# %% [markdown]
# To select one style

# %%
XML('<body><tag>content</tag></body>', expand=True, style="perldoc")
# Out:
#     <div class="a6209c39e-92b7-48a6-aebf-478ce8c9d149">
#         <style>
#             div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .hll { background-color: #ffffcc }
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .c { color: #228B22 } /* Comment */
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .err { color: #a61717; background-color: #e3d2d2 } /* Error */
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .k { color: #8B008B; font-weight: bold } /* Keyword */
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .ch { color: #228B22 } /* Comment.Hashbang */
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .cm { color: #228B22 } /* Comment.Multiline */
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .cp { color: #1e889b } /* Comment.Preproc */
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .cpf { color: #228B22 } /* Comment.PreprocFile */
# div.a6209c39e-92b7-48a6-aebf-478ce8c9d149 .c1 { color: #228B22 } /* Comment.Single */
# ...
